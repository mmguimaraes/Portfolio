# %% [markdown]
# # Linear Regression Project 2
#
# Our dataset this time is related to fuel consumption and Carbon dioxide emission of cars.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Reading the data

# %%
df = pd.read_csv('data/FuelConsumption.csv')
df.head()
# Out:
#    Unnamed: 0  MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  \
# 0           0       2014  ACURA         ILX      COMPACT         2.0
# 1           1       2014  ACURA         ILX      COMPACT         2.4
# 2           2       2014  ACURA  ILX HYBRID      COMPACT         1.5
# 3           3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5
# 4           4       2014  ACURA     RDX AWD  SUV - SMALL         3.5
#
#    CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          4          AS5        Z                   9.9                  6.7
# 1          4           M6        Z                  11.2                  7.7
# 2          4          AV7        Z                   6.0                  5.8
# 3          6          AS6        Z                  12.7                  9.1
# 4          6          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# ...

# %% [markdown]
# ### Describing the dataset.
#
# We have a fuel consumption dataset which contains model-specific fuel consumption ratings and estimated carbon dioxide emissions for new light-duty vehicles for retail sale in Canada. [Dataset source](http://open.canada.ca/data/en/dataset/98f1a129-f628-4ce4-b24d-6f16bf24dd64)
#
# - **MODELYEAR** e.g. 2014
# - **MAKE** e.g. Acura
# - **MODEL** e.g. ILX
# - **VEHICLE CLASS** e.g. SUV
# - **ENGINE SIZE** e.g. 4.7
# - **CYLINDERS** e.g 6
# - **TRANSMISSION** e.g. A6
# - **FUEL CONSUMPTION in CITY(L/100 km)** e.g. 9.9
# - **FUEL CONSUMPTION in HWY (L/100 km)** e.g. 8.9
# - **FUEL CONSUMPTION COMB (L/100 km)** e.g. 9.2
# - **CO2 EMISSIONS (g/km)** e.g. 182   --> low --> 0

# %% [markdown]
# ### Data Exploration

# %%
# summarize the data
df.describe().transpose()
# Out:
#                            count         mean         std     min      25%  \
# Unnamed: 0                1067.0   533.000000  308.160672     0.0   266.50
# MODELYEAR                 1067.0  2014.000000    0.000000  2014.0  2014.00
# ENGINESIZE                1067.0     3.346298    1.415895     1.0     2.00
# CYLINDERS                 1067.0     5.794752    1.797447     3.0     4.00
# FUELCONSUMPTION_CITY      1067.0    13.296532    4.101253     4.6    10.25
# FUELCONSUMPTION_HWY       1067.0     9.474602    2.794510     4.9     7.50
# FUELCONSUMPTION_COMB      1067.0    11.580881    3.485595     4.7     9.00
# FUELCONSUMPTION_COMB_MPG  1067.0    26.441425    7.468702    11.0    21.00
# CO2EMISSIONS              1067.0   256.228679   63.372304   108.0   207.00
#
#                              50%      75%     max
# Unnamed: 0                 533.0   799.50  1066.0
# MODELYEAR                 2014.0  2014.00  2014.0
# ENGINESIZE                   3.4     4.30     8.4
# ...

# %% [markdown]
# The maximum Fuel Consumption in the City is 30.2 liters per 100 km, while the minimum is 4.6. The maximum Fuel Consumption in the highway is 20.5 liters per 100 km, while the minimum is 4.9. And the maximum CO<sub>2</sub> emission is 488 g/km.

# %% [markdown]
# Lets select some features to explore more.

# %%
cdf = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %% [markdown]
# we can plot each of these features:

# %%
# Setting some seaborn parameters
sns.set_palette("Blues_r")
sns.set_style('whitegrid')
f, axes = plt.subplots(2, 2, figsize=(14, 10))
sns.distplot(cdf['CO2EMISSIONS'], kde=False, ax=axes[0, 0])
sns.distplot(cdf['CYLINDERS'], kde=False, ax=axes[0, 1])
sns.distplot(cdf['ENGINESIZE'], kde=False, ax=axes[1, 0])
sns.distplot(cdf['FUELCONSUMPTION_COMB'], kde=False, ax=axes[1, 1]);

# %% [markdown]
# Now, lets plot each of these features vs the Emission, to see how linear is their relation:

# %%
f, axes = plt.subplots(1, 3, figsize=(16, 10))
sns.scatterplot(x=df['FUELCONSUMPTION_COMB'],y=df['CO2EMISSIONS'],ax=axes[0])
sns.scatterplot(x=df['ENGINESIZE'],y=df['CO2EMISSIONS'],ax=axes[1])
sns.scatterplot(x=df['CYLINDERS'],y=df['CO2EMISSIONS'],ax=axes[2]);

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11, 8)
sns.scatterplot(x='ENGINESIZE',y='CO2EMISSIONS',data=df,hue='CYLINDERS',palette='viridis');

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11, 8)
sns.scatterplot(x='ENGINESIZE',y='CO2EMISSIONS',data=df,hue='FUELCONSUMPTION_COMB',palette='viridis');

# %%
cdf = df[['ENGINESIZE','FUELCONSUMPTION_CITY', 'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB','FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS']]

# %%
g = sns.pairplot(cdf)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot);

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='viridis');

# %% [markdown]
# ### Train and test split

# %%
from sklearn.model_selection import train_test_split

# %%
#X = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']]
X = df[['ENGINESIZE']]
y = df[['CO2EMISSIONS']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ### Train data
#
# We will focus right now only on the Engine Size.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11, 8)
sns.scatterplot(x='ENGINESIZE',y='CO2EMISSIONS',data=df);

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#             Coefficient
# ENGINESIZE    39.545285

# %% [markdown]
# ### Predicting

# %%
predict = lm.predict(X_test)
plt.scatter(y_test,predict)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y');

# %% [markdown]
# ### Evaluation

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predict))
print('MSE:', metrics.mean_squared_error(y_test, predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predict)))
# Out:
# MAE: 22.91090644129924
# MSE: 886.7348973194676
# RMSE: 29.77809425264598

# %%
# Residuals
sns.distplot(y_test - predict, bins=20);
